# %%
library(lme4)
library(lmerTest)
library(nlme)
library(ggplot2)
library(grid)
library(gridExtra)
library(lattice)
library(plyr)
library(MASS)
library(stats4)
library(dplyr)
library(car)

# %%
data_raw <- read.table("/Users/hutianqi/Desktop/Project Risk and Intelligence/01 Dataset/Trials.csv", header=TRUE, sep=",")

# make a copy of mydata where less than 300ms and more than 10s rounds are rejected
data <- subset(data_raw, RT > .3 & RT < 10)

# trials in advantageous domain where gain > loss
data1 <- subset(data, domain_group == 1)
# trials in disadvantageous domain where gain < loss
data2 <- subset(data, domain_group == 2)
# trials in neutral domain where gain = loss
data3 <- subset(data, domain_group == 3)

# %%
names(data)
# Out:
#  [1] "subject"      "trial"        "display"      "gain"         "loss"
#  [6] "stake"        "gain_adv"     "RT"           "accept"       "gender"
# [11] "age"          "valid_trials" "RS"           "IS"           "PSA"
# [16] "NGA"          "RTP_E"        "RTP_F"        "RTP_FI"       "RTP_FG"
# [21] "RTP_HS"       "RTP_R"        "RTP_S"        "RTP_average"  "domain_group"
# [26] "CRT_group"    "RS_group"     "IS_group"     "residual"     "RS_level"
# [31] "RS_low"       "RS_mid"       "RS_high"

# %%
### Baseline model
summary(glmer(accept ~ scale(gain_adv)*scale(stake) + scale(age) + factor(gender) + (1|subject), data, family=binomial(link = "logit")))
# Out:
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: binomial  ( logit )
# Formula:
# accept ~ scale(gain_adv) * scale(stake) + scale(age) + factor(gender) +
#     (1 | subject)
#    Data: data
#
#      AIC      BIC   logLik deviance df.resid
#  14580.8  14637.4  -7283.4  14566.8    24047
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -64.123  -0.298  -0.064   0.237  63.206
#
# Random effects:
#  Groups  Name        Variance Std.Dev.
#  subject (Intercept) 2.372    1.54
# Number of obs: 24054, groups:  subject, 122
#
# Fixed effects:
#                               Estimate Std. Error z value Pr(>|z|)
# (Intercept)                  -1.304454   0.200299  -6.513 7.39e-11 ***
# scale(gain_adv)               3.183520   0.043890  72.534  < 2e-16 ***
# scale(stake)                 -0.304628   0.019856 -15.342  < 2e-16 ***
# scale(age)                    0.100414   0.141010   0.712    0.476
# ...

# %%
### RS as a continuous score
summary(glmer(accept ~ scale(gain_adv)*scale(stake) + scale(age) + gender + scale(RS) + (1|subject), data, family=binomial(link = "logit")))

summary(glmer(accept ~ scale(gain_adv)*scale(stake) + scale(age) + gender + scale(RS) + (1|subject), data1, family=binomial(link = "logit")))

summary(glmer(accept ~ scale(gain_adv)*scale(stake) + scale(age) + gender + scale(RS) + (1|subject), data2, family=binomial(link = "logit")))
# Out:
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: binomial  ( logit )
# Formula: accept ~ scale(gain_adv) * scale(stake) + scale(age) + gender +
#     scale(RS) + (1 | subject)
#    Data: data
#
#      AIC      BIC   logLik deviance df.resid
#  14577.5  14642.2  -7280.8  14561.5    24046
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -64.471  -0.299  -0.064   0.238  62.694
#
# Random effects:
#  Groups  Name        Variance Std.Dev.
#  subject (Intercept) 2.267    1.506
# Number of obs: 24054, groups:  subject, 122
#
# Fixed effects:
#                              Estimate Std. Error z value Pr(>|z|)
# (Intercept)                  -1.41429    0.20158  -7.016 2.29e-12 ***
# scale(gain_adv)               3.18350    0.04389  72.533  < 2e-16 ***
# scale(stake)                 -0.30467    0.01986 -15.344  < 2e-16 ***
# scale(age)                    0.05299    0.13945   0.380    0.704
# ...

# %%
### IS as a continuous score
summary(glmer(accept ~ scale(gain_adv)*scale(stake) + scale(age) + gender + scale(IS) + (1|subject), data, family=binomial(link = "logit")))

summary(glmer(accept ~ scale(gain_adv)*scale(stake) + scale(age) + gender + scale(IS) + (1|subject), data1, family=binomial(link = "logit")))

summary(glmer(accept ~ scale(gain_adv)*scale(stake) + scale(age) + gender + scale(IS) + (1|subject), data2, family=binomial(link = "logit")))
# Out:
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: binomial  ( logit )
# Formula: accept ~ scale(gain_adv) * scale(stake) + scale(age) + gender +
#     scale(IS) + (1 | subject)
#    Data: data
#
#      AIC      BIC   logLik deviance df.resid
#  14579.2  14643.9  -7281.6  14563.2    24046
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -64.416  -0.299  -0.064   0.238  62.905
#
# Random effects:
#  Groups  Name        Variance Std.Dev.
#  subject (Intercept) 2.3      1.517
# Number of obs: 24054, groups:  subject, 122
#
# Fixed effects:
#                              Estimate Std. Error z value Pr(>|z|)
# (Intercept)                  -1.37941    0.20118  -6.856 7.06e-12 ***
# scale(gain_adv)               3.18347    0.04389  72.534  < 2e-16 ***
# scale(stake)                 -0.30467    0.01986 -15.343  < 2e-16 ***
# scale(age)                    0.06537    0.14012   0.467    0.641
# ...

# %%
### NGA as a continuous score
summary(glmer(accept ~ scale(gain_adv)*scale(stake) + scale(age) + gender + scale(NGA) + (1|subject), data, family=binomial(link = "logit")))
summary(glmer(accept ~ scale(gain_adv)*scale(stake) + scale(age) + gender + scale(NGA) + (1|subject), data1, family=binomial(link = "logit")))
summary(glmer(accept ~ scale(gain_adv)*scale(stake) + scale(age) + gender + scale(NGA) + (1|subject), data2, family=binomial(link = "logit")))
# Out:
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: binomial  ( logit )
# Formula: accept ~ scale(gain_adv) * scale(stake) + scale(age) + gender +
#     scale(NGA) + (1 | subject)
#    Data: data
#
#      AIC      BIC   logLik deviance df.resid
#  14582.6  14647.3  -7283.3  14566.6    24046
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -64.100  -0.298  -0.064   0.237  63.191
#
# Random effects:
#  Groups  Name        Variance Std.Dev.
#  subject (Intercept) 2.368    1.539
# Number of obs: 24054, groups:  subject, 122
#
# Fixed effects:
#                              Estimate Std. Error z value Pr(>|z|)
# (Intercept)                  -1.31105    0.20067  -6.533 6.43e-11 ***
# scale(gain_adv)               3.18352    0.04389  72.534  < 2e-16 ***
# scale(stake)                 -0.30462    0.01986 -15.342  < 2e-16 ***
# scale(age)                    0.10836    0.14203   0.763    0.446
# ...

# %%
### PSA as a continuous score
summary(glmer(accept ~ scale(gain_adv)*scale(stake) + scale(age) + gender + scale(PSA) + (1|subject), data, family=binomial(link = "logit")))
summary(glmer(accept ~ scale(gain_adv)*scale(stake) + scale(age) + gender + scale(PSA) + (1|subject), data1, family=binomial(link = "logit")))
summary(glmer(accept ~ scale(gain_adv)*scale(stake) + scale(age) + gender + scale(PSA) + (1|subject), data2, family=binomial(link = "logit")))
# Out:
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: binomial  ( logit )
# Formula: accept ~ scale(gain_adv) * scale(stake) + scale(age) + gender +
#     scale(PSA) + (1 | subject)
#    Data: data
#
#      AIC      BIC   logLik deviance df.resid
#  14580.2  14644.9  -7282.1  14564.2    24046
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -64.416  -0.298  -0.064   0.238  63.018
#
# Random effects:
#  Groups  Name        Variance Std.Dev.
#  subject (Intercept) 2.321    1.523
# Number of obs: 24054, groups:  subject, 122
#
# Fixed effects:
#                              Estimate Std. Error z value Pr(>|z|)
# (Intercept)                  -1.29371    0.19828  -6.525 6.82e-11 ***
# scale(gain_adv)               3.18350    0.04389  72.534  < 2e-16 ***
# scale(stake)                 -0.30464    0.01986 -15.342  < 2e-16 ***
# scale(age)                    0.10520    0.13955   0.754    0.451
# ...

# %%
### NGA and PSA as a continuous score
summary(glmer(accept ~ scale(gain_adv)*scale(stake) + scale(age) + gender + scale(NGA)*scale(PSA) + (1|subject), data, family=binomial(link = "logit")))
summary(glmer(accept ~ scale(gain_adv)*scale(stake) + scale(age) + gender + scale(NGA)*scale(PSA) + (1|subject), data1, family=binomial(link = "logit")))
summary(glmer(accept ~ scale(gain_adv)*scale(stake) + scale(age) + gender + scale(NGA)*scale(PSA) + (1|subject), data2, family=binomial(link = "logit")))
# Out:
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: binomial  ( logit )
# Formula: accept ~ scale(gain_adv) * scale(stake) + scale(age) + gender +
#     scale(NGA) * scale(PSA) + (1 | subject)
#    Data: data
#
#      AIC      BIC   logLik deviance df.resid
#  14582.4  14663.3  -7281.2  14562.4    24044
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -64.512  -0.298  -0.064   0.238  62.991
#
# Random effects:
#  Groups  Name        Variance Std.Dev.
#  subject (Intercept) 2.287    1.512
# Number of obs: 24054, groups:  subject, 122
#
# Fixed effects:
#                              Estimate Std. Error z value Pr(>|z|)
# (Intercept)                  -1.33404    0.19976  -6.678 2.42e-11 ***
# scale(gain_adv)               3.18352    0.04389  72.533  < 2e-16 ***
# scale(stake)                 -0.30463    0.01986 -15.342  < 2e-16 ***
# scale(age)                    0.13388    0.14027   0.955   0.3398
# ...

# %%
### RS and NGA as a continuous score
summary(glmer(accept ~ scale(gain_adv)*scale(stake) + scale(age) + gender + scale(RS)*scale(NGA) + (1|subject), data, family=binomial(link = "logit")))
summary(glmer(accept ~ scale(gain_adv)*scale(stake) + scale(age) + gender + scale(RS)*scale(NGA) + (1|subject), data1, family=binomial(link = "logit")))
summary(glmer(accept ~ scale(gain_adv)*scale(stake) + scale(age) + gender + scale(RS)*scale(NGA) + (1|subject), data2, family=binomial(link = "logit")))
# Out:
# Generalized linear mixed model fit by maximum likelihood (Laplace
#   Approximation) [glmerMod]
#  Family: binomial  ( logit )
# Formula: accept ~ scale(gain_adv) * scale(stake) + scale(age) + gender +
#     scale(RS) * scale(NGA) + (1 | subject)
#    Data: data
#
#      AIC      BIC   logLik deviance df.resid
#  14579.2  14660.1  -7279.6  14559.2    24044
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -64.334  -0.299  -0.064   0.238  62.592
#
# Random effects:
#  Groups  Name        Variance Std.Dev.
#  subject (Intercept) 2.223    1.491
# Number of obs: 24054, groups:  subject, 122
#
# Fixed effects:
#                              Estimate Std. Error z value Pr(>|z|)
# (Intercept)                  -1.42586    0.20023  -7.121 1.07e-12 ***
# scale(gain_adv)               3.18350    0.04389  72.534  < 2e-16 ***
# scale(stake)                 -0.30467    0.01986 -15.344  < 2e-16 ***
# scale(age)                    0.05079    0.13938   0.364   0.7156
# ...
